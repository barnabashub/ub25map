# %%
import folium
import pandas as pd
import random
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
from folium.plugins import MarkerCluster

# Load data from CSV with correct delimiter
df = pd.read_csv("runners.csv", delimiter=";")

# Function to get coordinates
def get_coordinates(location):
    geolocator = Nominatim(user_agent="relay_race")
    try:
        loc = geolocator.geocode(location)
        if loc:
            return (loc.latitude, loc.longitude)
    except GeocoderTimedOut:
        return None
    return None

# Get coordinates for all unique locations
locations = {loc: get_coordinates(loc) for loc in set(df["Start"].tolist() + df["End"].tolist())}

# Generate random colors for runners
runners = df["Runner"].unique()
colors = {runner: "#%06x" % random.randint(0, 0xFFFFFF) for runner in runners}

# Initialize Map
m = folium.Map(location=list(locations.values())[0], zoom_start=13)
marker_cluster = MarkerCluster().add_to(m)

# Plot routes and markers
for index, row in df.iterrows():
    start, end = locations.get(row["Start"]), locations.get(row["End"])
    if start and end:
        folium.PolyLine([start, end], color=colors[row["Runner"]], weight=5, opacity=0.7).add_to(m)
        folium.Marker(
            start,
            popup=f"{row['Runner']}<br>Start: {row['Start']}<br>Length: {row['Length']}<br>Time: {row['Time']}",
            icon=folium.Icon(color="blue")
        ).add_to(marker_cluster)
        folium.Marker(
            end,
            popup=f"{row['Runner']}<br>End: {row['End']}<br>Length: {row['Length']}<br>Time: {row['Time']}",
            icon=folium.Icon(color="red")
        ).add_to(marker_cluster)

# Display Map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_adec5513360f36cf49ff8817ba700373 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_adec5513360f36cf49ff8817ba700373&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_adec5513360f36cf49ff8817ba700373 = L.map(
#                 &quot;map_adec5513360f36cf49ff8817ba700373&quot;,
#                 {
#                     center: [46.7675081, 17.2462801],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4fe04e69beae9607ebb676634d1de9b4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4fe04e69beae9607ebb676634d1de9b4.addTo(map_adec5513360f36cf49ff8817ba700373);
#
#
#             var marker_cluster_14f7b390926555ffa8ef6fc8a7a45513 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_bf09e059e5db6bf33c508e5cb6f61189 = L.marker(
#                 [46.9567254, 17.888892],
#                 {
# }
#             ).addTo(marker_cluster_14f7b390926555ffa8ef6fc8a7a45513);
#
#
#             var icon_0a82cefd23915c5b8d0e390c41d105ec = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_21f1bdbbd8129cd0f4ef8f3d79c53261 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0cd16d871c06a44ac259da03bcee349 = $(`&lt;div id=&quot;html_a0cd16d871c06a44ac259da03bcee349&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Benci&lt;br&gt;Start: Balatonfüred&lt;br&gt;Length: 11,7&lt;br&gt;Time: 17:24:31&lt;/div&gt;`)[0];
#                 popup_21f1bdbbd8129cd0f4ef8f3d79c53261.setContent(html_a0cd16d871c06a44ac259da03bcee349);
#
#
#
#         marker_bf09e059e5db6bf33c508e5cb6f61189.bindPopup(popup_21f1bdbbd8129cd0f4ef8f3d79c53261)
#         ;
#
#
#
#
#                 marker_bf09e059e5db6bf33c508e5cb6f61189.setIcon(icon_0a82cefd23915c5b8d0e390c41d105ec);
#
#
#             var marker_dd4b82aa65cc97f5923cd2cfe40426fa = L.marker(
#                 [46.897453, 17.7920258],
#                 {
# }
#             ).addTo(marker_cluster_14f7b390926555ffa8ef6fc8a7a45513);
#
#
#             var icon_3cb24c2c7792e9be31d56a862cfd6f3e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_541bed516544f6412d384068427bc6a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab71f67265df3f9679ffd4f50db427ee = $(`&lt;div id=&quot;html_ab71f67265df3f9679ffd4f50db427ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Benci&lt;br&gt;End: Fövenyes&lt;br&gt;Length: 11,7&lt;br&gt;Time: 17:24:31&lt;/div&gt;`)[0];
#                 popup_541bed516544f6412d384068427bc6a1.setContent(html_ab71f67265df3f9679ffd4f50db427ee);
#
#
#
#         marker_dd4b82aa65cc97f5923cd2cfe40426fa.bindPopup(popup_541bed516544f6412d384068427bc6a1)
#         ;
#
#
#
#
#                 marker_dd4b82aa65cc97f5923cd2cfe40426fa.setIcon(icon_3cb24c2c7792e9be31d56a862cfd6f3e);
#
#
#             var marker_46fe77e6c01d83e17daad59de7d9e148 = L.marker(
#                 [46.897453, 17.7920258],
#                 {
# }
#             ).addTo(marker_cluster_14f7b390926555ffa8ef6fc8a7a45513);
#
#
#             var icon_32726de1c56740d418000f8f854aa759 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7cc5b111d5488d870bf3438986851ea4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_242bf7d92daef895d6557fad065f7406 = $(`&lt;div id=&quot;html_242bf7d92daef895d6557fad065f7406&qu

# %%
import folium
import pandas as pd
import random
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

# Load data from CSV with correct delimiter
df = pd.read_csv("runners.csv", delimiter=";")

# Function to get coordinates
def get_coordinates(location):
    geolocator = Nominatim(user_agent="relay_race")
    try:
        loc = geolocator.geocode(location)
        if loc:
            return (loc.latitude, loc.longitude)
    except GeocoderTimedOut:
        return None
    return None

# Get coordinates for all unique locations
locations = {loc: get_coordinates(loc) for loc in set(df["Start"].tolist() + df["End"].tolist())}

# Generate random colors for runners
runners = df["Runner"].unique()
colors = {runner: "#%06x" % random.randint(0, 0xFFFFFF) for runner in runners}

# Initialize Map
m = folium.Map(location=list(locations.values())[0], zoom_start=13)

# Plot routes and add text labels
for index, row in df.iterrows():
    start, end = locations.get(row["Start"]), locations.get(row["End"])
    if start and end:
        folium.PolyLine([start, end], color=colors[row["Runner"]], weight=5, opacity=0.7).add_to(m)

        folium.Marker(
            end,
            icon=folium.DivIcon(html=f'<div style="font-size: 12px; color: black; background: white; padding: 2px; border-radius: 3px; width: 50px;">{row["Runner"]} ({row["Length"]} km, {row["Time"]})</div>')
        ).add_to(m)

# Display Map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b20213a76ab9db8ecbc864afa7974551 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b20213a76ab9db8ecbc864afa7974551&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b20213a76ab9db8ecbc864afa7974551 = L.map(
#                 &quot;map_b20213a76ab9db8ecbc864afa7974551&quot;,
#                 {
#                     center: [46.7675081, 17.2462801],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aec633ed4a1f9bc5678565608acffe13 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aec633ed4a1f9bc5678565608acffe13.addTo(map_b20213a76ab9db8ecbc864afa7974551);
#
#
#             var poly_line_39d3a88ff459ca7e36fb38ab8f8213b4 = L.polyline(
#                 [[46.9567254, 17.888892], [46.897453, 17.7920258]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f04a75&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#f04a75&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_b20213a76ab9db8ecbc864afa7974551);
#
#
#             var marker_f4fa8c284fd83a79558191434103794a = L.marker(
#                 [46.897453, 17.7920258],
#                 {
# }
#             ).addTo(map_b20213a76ab9db8ecbc864afa7974551);
#
#
#             var div_icon_54bc9bec64f6bd7fd47e6d7fbbdd6079 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color: black; background: white; padding: 2px; border-radius: 3px; width: 50px;\&quot;\u003eBenci (11,7 km, 17:24:31)\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_f4fa8c284fd83a79558191434103794a.setIcon(div_icon_54bc9bec64f6bd7fd47e6d7fbbdd6079);
#
#
#                 marker_f4fa8c284fd83a79558191434103794a.setIcon(div_icon_54bc9bec64f6bd7fd47e6d7fbbdd6079);
#
#
#             var poly_line_dbdaea1e40260c0a889ce37a8ef41a89 = L.polyline(
#                 [[46.897453, 17.7920258], [46.8775697, 17.7088425]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#7c21f6&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#7c21f6&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_b20213a76ab9db8ecbc864afa7974551);
#
#
#             var marker_45dcd2d2a6114ac3f0e20fbd557fe585 = L.marker(
#                 [46.8775697, 17.7088425],
#                 {
# }
#             ).addTo(map_b20213a76ab9db8ecbc864afa7974551);
#
#
#             var div_icon_277b9ee0e5d576778bd5772c1a3fa7f7 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color: black; background: white; padding: 2px; border-radius: 3px; width: 50px;\&quot;\u003eT\u00f3th G\u00e1bor (8,3 km, 18:17:09)\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_45dcd2d2a6114ac3f0e20fbd557fe585.setIcon(div_icon_277b9ee0e5d576778bd5772c1a3fa7f7);
#
#
#                 marker_45dcd2d2a6114ac3f0e20fbd557fe585.setIcon(div_icon_277b9ee0e5d576778bd5772c1a3fa7f7);
#
#
#             var poly_line_ced0e04ca63aa06df50b6c30d91a0ee3 = L.polyline(
#                 [[46.8775697, 17.7088425], [46.8518266, 17.6637569]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#94973e&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#94973e&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_b20213a76ab9db8ecbc864afa7974551);
#
#
#             var marker_f13266c69d80fd8da1afdb35b80f3040 = L.marker(
#                 [46.8518266, 17.6637569],
#                 {
# }
#             ).addTo(map_b20213a76ab9db8ecbc864afa7974551);
#
#
#             var div_icon_c5ff8b551b24a6d70aa40012a998b221 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color: black; background: white

# %%
import folium
import pandas as pd
import random
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

# Load data from CSV with correct delimiter
df = pd.read_csv("runners.csv", delimiter=";")

# Function to get coordinates
def get_coordinates(location):
    geolocator = Nominatim(user_agent="relay_race")
    try:
        loc = geolocator.geocode(location)
        if loc:
            return (loc.latitude, loc.longitude)
    except GeocoderTimedOut:
        return None
    return None

# Get coordinates for all unique locations
locations = {loc: get_coordinates(loc) for loc in set(df["Start"].tolist() + df["End"].tolist())}

# Generate random colors for runners
runners = df["Runner"].unique()
colors = {runner: "#%06x" % random.randint(0, 0xFFFFFF) for runner in runners}

# Initialize Map
geolocator = Nominatim(user_agent="relay_race")
balaton_coords = geolocator.geocode("Balaton")
map_center = (balaton_coords.latitude, balaton_coords.longitude)
m = folium.Map( zoom_start=10, location=map_center)

# Offset values to avoid overlap
offset = 0.002

def add_label_with_leader(start, end, text):
    mid_point = ((start[0] + end[0]) / 2, (start[1] + end[1]) / 2)
    label_position = (mid_point[0] + offset, mid_point[1] + offset)
    folium.PolyLine([mid_point, label_position], color="black", weight=1, dash_array="5,5").add_to(m)
    folium.Marker(
        label_position,
        icon=folium.DivIcon(html=f'<div style="font-size: 12px; color: black; background-color:rgba(255, 255, 255, 0.4); padding: 5px; border-radius: 5px; white-space: nowrap; width: 250px;">{text}</div>')
    ).add_to(m)

# Plot routes and add text labels
for index, row in df.iterrows():
    start, end = locations.get(row["Start"]), locations.get(row["End"])
    if start and end:
        folium.PolyLine([start, end], color=colors[row["Runner"]], weight=5, opacity=0.7).add_to(m)
        text = f"{row['Runner']} ({row['Length']} km, {row['Time']})"
        add_label_with_leader(start, end, text)


# Display Map
geolocator = Nominatim(user_agent="relay_race")
balaton_coords = geolocator.geocode("Balaton")
map_center = (balaton_coords.latitude, balaton_coords.longitude)
folium.Map(location=map_center, zoom_start=10)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50a79e622ce7a2ff2ae237a546cc9d85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50a79e622ce7a2ff2ae237a546cc9d85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50a79e622ce7a2ff2ae237a546cc9d85 = L.map(
#                 &quot;map_50a79e622ce7a2ff2ae237a546cc9d85&quot;,
#                 {
#                     center: [46.8839313, 17.847679598118443],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d4340ccfb5fcef72cbecfeb29f017c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8d4340ccfb5fcef72cbecfeb29f017c1.addTo(map_50a79e622ce7a2ff2ae237a546cc9d85);
#
#
#             var poly_line_f9a032377c7f3a4a3e956775ee3b0b7a = L.polyline(
#                 [[46.9567254, 17.888892], [46.897453, 17.7920258]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#5bd78b&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#5bd78b&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_50a79e622ce7a2ff2ae237a546cc9d85);
#
#
#             var poly_line_8794087bd69cc4baac50d1b5e17e3474 = L.polyline(
#                 [[46.9270892, 17.8404589], [46.9290892, 17.8424589]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5,5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_50a79e622ce7a2ff2ae237a546cc9d85);
#
#
#             var marker_087c9f985a146ee4490319aef32ad71d = L.marker(
#                 [46.9290892, 17.8424589],
#                 {
# }
#             ).addTo(map_50a79e622ce7a2ff2ae237a546cc9d85);
#
#
#             var div_icon_183213b5a15cb0dc2738030a03c95b47 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color: black; background-color:rgba(255, 255, 255, 0.4); padding: 5px; border-radius: 5px; white-space: nowrap; width: 250px;\&quot;\u003eBenci (11,7 km, 17:24:31)\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_087c9f985a146ee4490319aef32ad71d.setIcon(div_icon_183213b5a15cb0dc2738030a03c95b47);
#
#
#                 marker_087c9f985a146ee4490319aef32ad71d.setIcon(div_icon_183213b5a15cb0dc2738030a03c95b47);
#
#
#             var poly_line_24ac3cd65ce478b242d2fa8fc2d2c157 = L.polyline(
#                 [[46.897453, 17.7920258], [46.8775697, 17.7088425]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#165e2c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#165e2c&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.7, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_50a79e622ce7a2ff2ae237a546cc9d85);
#
#
#             var poly_line_43e9f47123487157dfd4d2fda4aa0bea = L.polyline(
#                 [[46.88751135, 17.75043415], [46.88951135, 17.75243415]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: &quot;5,5&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;black&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_50a79e622ce7a2ff2ae237a546cc9d85);
#
#
#             var marker_68902791f47e5db389778fed2332d690 = L.marker(
#                 [46.88951135, 17.75243415],
#                 {
# }
#             ).addTo(map_50a79e622ce7a2ff2ae237a546cc9d85);
#
#
#             var div_icon_8ce8a1f23f26d15b024bea8b1d8f71ea = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color: black; bac

# %%
# prompt: export m map in high resolution picture

m.save("relay_race_map.html")
